# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
data= pd.read_csv("Valencia_IQR.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9447 entries, 0 to 9446
# Data columns (total 54 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0.2                                     9447 non-null   int64
#  1   fuente                                           9447 non-null   object
#  2   nombre                                           9447 non-null   object
#  3   descripción                                      9447 non-null   object
#  4   descripción general del vecindario               9447 non-null   object
#  5   nombre_host                                      9447 non-null   object
#  6   tiempo_respuesta_host                            9447 non-null   object
#  7   tasa_respuesta_host                              9447 non-null   object
#  8   tasa_de_aceptación_host                          9447 non-null   object
# ...

# %%
data.head()
n=50

# %%
freq_tbl(data)
# Out:
#             fuente  frequency  percentage  cumulative_perc
# 0      city scrape       8640    0.914576         0.914576
# 1  previous scrape        807    0.085424         1.000000
#
# ----------------------------------------------------------------
#
#                                                  nombre  frequency  \
# 0     BM Bright Urban Style apartment close to the b...        104
# 1                 Cozy studio near Valencia city centre         80
# 2       Modern studio a few blocks away from the centre         50
# 3                               HabitaciÃ³n en Valencia         21
# 4                         HabitaciÃ³n con baÃ±o privado         14
# ...                                                 ...        ...
# 8813            Newly renovated flat in historic center          1
# 8814                                          Easytimes          1
# 8815             HabitaciÃ³n Doble con baÃ±o compartido          1
# ...

# %% [markdown]
# __1) SOURCE__

# %%
table1= freq_tbl(data['fuente'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('fuente')
filtro_index
# Out:
#                  frequency
# fuente
# city scrape           8640
# previous scrape        807

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="skyblue")
plt.title('Fuente de datos')
plt.xlabel('Source')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __2) host response time__

# %%
table1= freq_tbl(data['tiempo_respuesta_host'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('tiempo_respuesta_host')
filtro_index
# Out:
#                        frequency
# tiempo_respuesta_host
# within an hour              6909
# within a few hours          1045
# No mentioned                 643
# within a day                 502
# a few days or more           348

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="gray")
plt.title('Fuente de datos')
plt.xlabel('tiempo_respuesta_host')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __3) host is superhost__

# %%
table1= freq_tbl(data['host_is_superhost'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>100]
filtro_index= filtro.set_index('host_is_superhost')
filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                       6578
# t                       2525
# No mencionado            344

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['red', 'green', 'gray'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __4) neighbourhood group cleansed__

# %%
table1= freq_tbl(data['grupo_vecindario_limpiado'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('grupo_vecindario_limpiado')
filtro_index
# Out:
#                            frequency
# grupo_vecindario_limpiado
# POBLATS MARITIMS                1805
# CIUTAT VELLA                    1570
# CAMINS AL GRAU                   862
# QUATRE CARRERES                  809
# L'EIXAMPLE                       794
# EXTRAMURS                        724
# LA SAIDIA                        533
# ALGIROS                          406
# JESUS                            299
# L'OLIVERETA                      294
# PATRAIX                          217
# BENICALAP                        204
# RASCANYA                         196
# POBLATS DEL SUD                  194
# EL PLA DEL REAL                  191
# CAMPANAR                         147
# BENIMACLET                       142
# POBLATS DE L'OEST                 48
# POBLATS DEL NORD                  12

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="orange")
plt.title('Fuente de datos')
plt.xlabel('grupo_vecindario_limpiado')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __5) room type__

# %%
table1= freq_tbl(data['tipo_habitación'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('tipo_habitación')
filtro_index
# Out:
#                  frequency
# tipo_habitación
# Entire home/apt       6721
# Private room          2659
# Shared room             53
# Hotel room              14

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="brown")
plt.title('Fuente de datos')
plt.xlabel('tipo_habitación')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __6) reservable al instante__

# %%
table1= freq_tbl(data['reservable_instantáneamente'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('reservable_instantáneamente')
filtro_index
# Out:
#                              frequency
# reservable_instantáneamente
# f                                 5462
# t                                 3985

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['red', 'green'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __7) tipo de propiedad__

# %%
table1= freq_tbl(data['tipo_propiedad'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>10]
filtro_index= filtro.set_index('tipo_propiedad')
filtro_index
# Out:
#                                     frequency
# tipo_propiedad
# Entire rental unit                       5446
# Private room in rental unit              2064
# Entire loft                               533
# Entire home                               240
# Entire condo                              224
# Private room in home                      175
# Private room in condo                     127
# Entire serviced apartment                 105
# Private room in bed and breakfast          81
# Private room in casa particular            64
# Entire vacation home                       48
# Room in hotel                              45
# Room in boutique hotel                     39
# Entire townhouse                           36
# Room in aparthotel                         26
# Private room in hostel                     25
# Shared room in rental unit                 22
# Entire guest suite                         16
# Shared room in hotel                       16
# ...

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Fuente de datos')
plt.xlabel('tipo_propiedad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __8) tiene_disponibilidad__

# %%
table1= freq_tbl(data['tiene_disponibilidad'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('tiene_disponibilidad')
filtro_index
# Out:
#                       frequency
# tiene_disponibilidad
# t                          9244
# No hay detalles             203

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['green', 'gray'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __9) accomodates__

# %%
table1 = data['se adapta'].value_counts().reset_index()
table1.columns = ['se adapta', 'frequency']
filtro = table1[table1['frequency'] >1]
filtro_index = filtro.set_index('se adapta')
filtro_index
# Out:
#            frequency
# se adapta
# 2.0             2916
# 4.0             2602
# 1.0             1033
# 6.0              938
# 3.0              816
# 5.0              682
# 3.2              348
# 7.0              112

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="gold")
plt.title('Fuente de datos')
plt.xlabel('accomodates')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __10) bathrooms__

# %%
table1 = data['baños'].value_counts().reset_index()
table1.columns = ['baños', 'frequency']
filtro = table1[table1['frequency'] >1]
filtro_index = filtro.set_index('baños')
filtro_index
# Out:
#           frequency
# baños
# 1              6035
# 2              1636
# Sin info        816
# 1.5             554
# 0.5             111
# 3                95
# 2.5              81
# 0                49
# 4                28
# 3.5              17
# 5                11
# 7                 5
# 6                 4
# 4.5               3

# %%
filtro_index.plot(kind='area',figsize=(10,4), alpha=1)
# Out:
# <Axes: xlabel='baños'>

# %% [markdown]
# __11) bedroom__

# %%
table1= freq_tbl(data['dormitorios'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>100]
filtro_index= filtro.set_index('dormitorios')
filtro_index
# Out:
#              frequency
# dormitorios
# 1                 4912
# 2                 2098
# 3                 1191
# 0                  582
# 4                  293
# Sin info           282

# %%
filtro_index.plot(kind='area',figsize=(10,4), alpha=1)
# Out:
# <Axes: xlabel='dormitorios'>

# %% [markdown]
# __12)beds__

# %%
table1= freq_tbl(data['camas'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>100]
filtro_index= filtro.set_index('camas')
filtro_index
# Out:
#           frequency
# camas
# 1              3210
# 2              2511
# 3              1393
# Sin info        813
# 4               780
# 5               284
# 0               229
# 6               116

# %%
filtro_index.plot(kind='area',figsize=(10,4), alpha=1)
# Out:
# <Axes: xlabel='camas'>

# %% [markdown]
# __13)neighbourhood_cleansed__

# %%
table1 = data['barrio_limpio'].value_counts().reset_index()
table1.columns = ['barrio_limpio', 'frequency']
filtro = table1[table1['frequency'] >99]
filtro_index = filtro.set_index('barrio_limpio')
filtro_index
# Out:
#                                       frequency
# barrio_limpio
# CABANYAL-CANYAMELAR                        1005
# RUSSAFA                                     646
# AIORA                                       405
# EL MERCAT                                   384
# EL CARME                                    337
# LA MALVA-ROSA                               310
# EL GRAU                                     305
# SANT FRANCESC                               288
# MORVEDRE                                    276
# MONT-OLIVET                                 265
# LA SEU                                      243
# ARRANCAPINS                                 242
# EN CORTS                                    241
# NOU MOLES                                   199
# BENICALAP                                   181
# LA ROQUETA                                  180
# EL PILAR                                    174
# EL BOTANIC                                  159
# ...

# %%
table1.plot('barrio_limpio', 'frequency',kind="scatter")
# Out:
# <Axes: xlabel='barrio_limpio', ylabel='frequency'>

# %% [markdown]
# __14)minimum_nights__

# %%
data.columns = data.columns.str.normalize('NFKC').str.replace(r'\xad', '', regex=True)
table1 = data['noches_mínimo'].value_counts().reset_index()
table1.columns = ['noches_mínimo', 'frequency']
filtro = table1[table1['frequency'] > 0]
filtro_index = filtro.set_index('noches_mínimo')
filtro_index
# Out:
#                frequency
# noches_mínimo
# 1.0                 3379
# 2.0                 2106
# 3.0                 1389
# 2.2                 1320
# 4.0                  568
# 5.0                  365
# 7.0                  201
# 6.0                  111
# 8.0                    8

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="black")
plt.title('Fuente de datos')
plt.xlabel('noches_minimo')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __15) calculated_host_listings_count__

# %%
table1 = data['calculado_host_listings_count'].value_counts().reset_index()
table1.columns = ['calculado_host_listings_count', 'frequency']
filtro = table1[table1['frequency'] >100]
filtro_index = filtro.set_index('calculado_host_listings_count')
filtro_index
# Out:
#                                frequency
# calculado_host_listings_count
# 1.0                                 3124
# 3.8                                 1475
# 2.0                                 1358
# 3.0                                  801
# 4.0                                  616
# 5.0                                  390
# 6.0                                  264
# 8.0                                  256
# 7.0                                  231
# 9.0                                  153
# 14.0                                 140

# %%
table1.plot('calculado_host_listings_count', 'frequency',kind="scatter")
# Out:
# <Axes: xlabel='calculado_host_listings_count', ylabel='frequency'>

# %% [markdown]
# __16) listados_host_calculados_recuento_casas_enteras__

# %%
table1 = data['listados_host_calculados_recuento_casas_enteras'].value_counts().reset_index()
table1.columns = ['listados_host_calculados_recuento_casas_enteras', 'frequency']
filtro = table1[table1['frequency'] >99]
filtro_index = filtro.set_index('listados_host_calculados_recuento_casas_enteras')
filtro_index
# Out:
#                                                  frequency
# listados_host_calculados_recuento_casas_enteras
# 1.0                                                   2516
# 0.0                                                   2266
# 2.4                                                   1563
# 2.0                                                    847
# 3.0                                                    583
# 4.0                                                    320
# 5.0                                                    262
# 8.0                                                    197
# 7.0                                                    173
# 6.0                                                    171
# 10.0                                                   157
# 9.0                                                    108

# %%
table1.plot('listados_host_calculados_recuento_casas_enteras', 'frequency',kind="scatter")
# Out:
# <Axes: xlabel='listados_host_calculados_recuento_casas_enteras', ylabel='frequency'>

# %% [markdown]
# __17) calculated_host_listings_count_shared_rooms__

# %%
table1 = data['calculado_host_listings_count_shared_rooms'].value_counts().reset_index()
table1.columns = ['calculado_host_listings_count_shared_rooms', 'frequency']
filtro = table1[table1['frequency'] >1]
filtro_index = filtro.set_index('calculado_host_listings_count_shared_rooms')
filtro_index
# Out:
#                                             frequency
# calculado_host_listings_count_shared_rooms
# 0                                                9447

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['gray'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __18) calculated_host_listings_count_private_rooms__

# %%
table1 = data['calculado_host_listings_count_private_rooms'].value_counts().reset_index()
table1.columns = ['calculado_host_listings_count_private_rooms', 'frequency']
filtro = table1[table1['frequency'] >1]
filtro_index = filtro.set_index('calculado_host_listings_count_private_rooms')
filtro_index
# Out:
#                                              frequency
# calculado_host_listings_count_private_rooms
# 0.0                                               6100
# 1.0                                               1366
# 0.3                                               1281
# 2.0                                                700

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['blue', 'skyblue', 'navy', 'royalblue'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __19) host id__

# %%
table1 = data['id_host'].value_counts().reset_index()
table1.columns = ['id_host', 'frequency']
filtro = table1[table1['frequency'] >99]
filtro_index = filtro.set_index('id_host')
filtro_index
# Out:
#            frequency
# id_host
# 134221412        156
# 417948112        137
# 83066665         116

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Fuente de datos')
plt.xlabel('id_host')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __20) nombre_host__

# %%
table1 = data['nombre_host'].value_counts().reset_index()
table1.columns = ['nombre_host', 'frequency']
filtro = table1[table1['frequency'] >99]
filtro_index = filtro.set_index('nombre_host')
filtro_index
# Out:
#                frequency
# nombre_host
# VLC Host             156
# Alexandra            150
# SingularStays        116
# Carlos               106

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%", colors=['green', 'pink', 'orange', 'blue'])
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# __Categorización de las variables__

# %% [markdown]
# __tasa_respuesta_host__

# %%
data['tasa_respuesta_host'] = data['tasa_respuesta_host'].str.rstrip('%').astype(float)

# %%
Max=data['tasa_respuesta_host'].max()
Min=data['tasa_respuesta_host'].min()
Limites =[Min,Max]
Limites
# Out:
# [0.0, 100.0]

# %%
Rango=Max-Min
Rango
# Out:
# 100.0

# %%
ni= 1 + 3.32*np.log10(n)
ni
# Out:
# 6.640580414395582

# %%
i=Rango/ni
i
# Out:
# 15.058924636048081

# %%
intervalos=np.linspace(Min,Max,16)
intervalos
# Out:
# array([  0.        ,   6.66666667,  13.33333333,  20.        ,
#         26.66666667,  33.33333333,  40.        ,  46.66666667,
#         53.33333333,  60.        ,  66.66666667,  73.33333333,
#         80.        ,  86.66666667,  93.33333333, 100.        ])

# %%
categorias= ["0 a 6.66", "6.66 a 13.33", "13.33 a 20", "20 a 26.66", "26.66 a 33.33", "33.33 a 40", "40 a 46.66" , "46.66 a 53.33", "53.33 a 60", "60 a 66.66", "66.66 a 73.33", "73.33 a 80", "80 a 86.66", "86.66 a 93.33", "93.33 a 100"]
data['tasa_respuesta_host']=pd.cut(x=data['tasa_respuesta_host'], bins=intervalos, labels=categorias)
data['tasa_respuesta_host']
# Out:
# 0         93.33 a 100
# 1         93.33 a 100
# 2         93.33 a 100
# 3          80 a 86.66
# 4       86.66 a 93.33
#             ...
# 9442              NaN
# 9443      93.33 a 100
# 9444              NaN
# 9445       53.33 a 60
# 9446       53.33 a 60
# Name: tasa_respuesta_host, Length: 9447, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
n_nombres = {
    "Categoría1": "0 a 6.66",
    "Categoría2": "6.66 a 13.33",
    "Categoría3": "13.33 a 20",
    "Categoría4": "20 a 26.66",
    "Categoría5": "26.66 a 33.33",
    "Categoría6": "33.33 a 40",
    "Categoría7": "40 a 46.66",
    "Categoría8": "46.66 a 53.33",
    "Categoría9": "53.33 a 60",
    "Categoría10": "60 a 66.66",
    "Categoría11": "66.66 a 73.33",
    "Categoría12": "73.33 a 80",
    "Categoría13": "80 a 86.66",
    "Categoría14": "86.66 a 93.33",
    "Categoría15": "93.33 a 100"
}

# Reemplazar los nombres de las categorías
data['tasa_respuesta_host'] = data['tasa_respuesta_host'].replace(n_nombres)

# %%
data['tasa_respuesta_host']
# Out:
# 0         93.33 a 100
# 1         93.33 a 100
# 2         93.33 a 100
# 3          80 a 86.66
# 4       86.66 a 93.33
#             ...
# 9442              NaN
# 9443      93.33 a 100
# 9444              NaN
# 9445       53.33 a 60
# 9446       53.33 a 60
# Name: tasa_respuesta_host, Length: 9447, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
table1= freq_tbl(data["tasa_respuesta_host"])
table1a= table1.drop(["cumulative_perc"], axis=1)
table1b= table1a.set_index("tasa_respuesta_host")
filtro=table1b[table1b['frequency']>50]
filtro
# Out:
#                      frequency  percentage
# tasa_respuesta_host
# 93.33 a 100               7206    0.762782
# 86.66 a 93.33              658    0.069652
# 73.33 a 80                 245    0.025934
# 66.66 a 73.33              159    0.016831
# 46.66 a 53.33               86    0.009103
# 80 a 86.66                  85    0.008998
# 26.66 a 33.33               63    0.006669

# %%
filtro.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Tasa de respuesta de host')
plt.xlabel('Porcentajes')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# __tasa_de_aceptación_host__

# %%
data['tasa_de_aceptación_host'] = data['tasa_de_aceptación_host'].str.rstrip('%').astype(float)

# %%
Maxhar=data['tasa_de_aceptación_host'].max()
Minhar=data['tasa_de_aceptación_host'].min()
Limites =[Minhar,Maxhar]
Rango=Maxhar-Minhar
ni= 1 + 3.32*np.log10(n)
iHar=Rango/ni
intervaloshar=np.linspace(Minhar,Maxhar,16)
categoriashar= ["0 a 6.66", "6.66 a 13.33", "13.33 a 20", "20 a 26.66", "26.66 a 33.33", "33.33 a 40", "40 a 46.66" , "46.66 a 53.33", "53.33 a 60", "60 a 66.66", "66.66 a 73.33", "73.33 a 80", "80 a 86.66", "86.66 a 93.33", "93.33 a 100"]
data['tasa_de_aceptación_host']=pd.cut(x=data['tasa_de_aceptación_host'], bins=intervaloshar, labels=categoriashar)
data['tasa_de_aceptación_host']
# Out:
# 0       86.66 a 93.33
# 1       86.66 a 93.33
# 2         93.33 a 100
# 3         93.33 a 100
# 4          73.33 a 80
#             ...
# 9442              NaN
# 9443       73.33 a 80
# 9444              NaN
# 9445       40 a 46.66
# 9446       40 a 46.66
# Name: tasa_de_aceptación_host, Length: 9447, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
tablehar= freq_tbl(data["tasa_de_aceptación_host"])
tablehar1= tablehar.drop(["cumulative_perc"], axis=1)
tablehar2= tablehar1.set_index("tasa_de_aceptación_host")
filtrohar=tablehar2[tablehar2['frequency']>150]
filtrohar
# Out:
#                          frequency  percentage
# tasa_de_aceptación_host
# 93.33 a 100                   6296    0.666455
# 86.66 a 93.33                  774    0.081931
# 80 a 86.66                     377    0.039907
# 73.33 a 80                     327    0.034614
# 66.66 a 73.33                  248    0.026252
# 46.66 a 53.33                  152    0.016090

# %%
filtrohar.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Tasa de aceptación del host')
plt.xlabel('Porcentajes')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# accomodates

# %%
Maxac=data['se adapta'].max()
Minac=data['se adapta'].min()
Limitesac =[Minac,Maxac]
Limitesac

Maxhar=data['se adapta'].max()
Minhar=data['se adapta'].min()
Limites =[Minhar,Maxhar]
Rango=Maxhar-Minhar
ni= 1 + 3.32*np.log10(n)
iHar=Rango/ni
intervaloshar=np.linspace(Minhar,Maxhar,16)
categoriashar= ["0 a 6.66", "6.66 a 13.33", "13.33 a 20", "20 a 26.66", "26.66 a 33.33", "33.33 a 40", "40 a 46.66" , "46.66 a 53.33", "53.33 a 60", "60 a 66.66", "66.66 a 73.33", "73.33 a 80", "80 a 86.66", "86.66 a 93.33", "93.33 a 100"]
data['se adapta']=pd.cut(x=data['se adapta'], bins=intervaloshar, labels=categoriashar)
data['se adapta']
# Out:
# 0       46.66 a 53.33
# 1         93.33 a 100
# 2          33.33 a 40
# 3          60 a 66.66
# 4       26.66 a 33.33
#             ...
# 9442              NaN
# 9443              NaN
# 9444       13.33 a 20
# 9445       13.33 a 20
# 9446    26.66 a 33.33
# Name: se adapta, Length: 9447, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
tablehar= freq_tbl(data["se adapta"])
tablehar1= tablehar.drop(["cumulative_perc"], axis=1)
tablehar2= tablehar1.set_index("se adapta")
filtrohar=tablehar2[tablehar2['frequency']>150]
filtrohar
# Out:
#                frequency  percentage
# se adapta
# 13.33 a 20          2916    0.308669
# 46.66 a 53.33       2602    0.275431
# 80 a 86.66           938    0.099291
# 26.66 a 33.33        816    0.086377
# 60 a 66.66           682    0.072192
# 33.33 a 40           348    0.036837

# %%
filtrohar.plot(kind = 'bar', width=0.8, figsize=(10,4), color="green")
plt.title('accomodates')
plt.xlabel('Porcentajes')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# beds

# %%
Maxac=data['camas'].max()
Minac=data['camas'].min()
Limitesac =[Minac,Maxac]
Limitesac
# Out:
# ['0', 'Sin info']

# %% [markdown]
# precio

# %%
MaxP=data['precio'].max()
MinP=data['precio'].min()
LimitesP =[MinP,MaxP]
LimitesP
# Out:
# ['$1,000.00', 'No asignado']

# %% [markdown]
# máximas_noches_avg_ntm

# %%
Maxmna=data['máximas_noches_avg_ntm'].max()
Minmna=data['máximas_noches_avg_ntm'].min()
Limitesmna =[Minmna,Maxmna]
Limitesmna
# Out:
# [1.0, 1125.0]

# %%
Rangomna=Maxmna-Minmna
Rangomna
# Out:
# 1124.0

# %%
imna=Rangomna/ni
imna
# Out:
# 169.26231290918042

# %%
intervalosmna=np.linspace(Minmna,Maxmna,16)
intervalosmna = [1, 142.6, 284.2, 425.8, 567.4, 709, 850.6, 992.2, 1125.0]
intervalosmna
# Out:
# [1, 142.6, 284.2, 425.8, 567.4, 709, 850.6, 992.2, 1125.0]

# %%
categoriasmna = ["1 a 142.6", "142.6 a 284.2", "284.2 a 425.8", "425.8 a 567.4", "567.4 a 709", "709 a 850.6", "850.6 a 992.2", "992.2 a 1125-0"]
data['máximas_noches_avg_ntm']=pd.cut(x=data['máximas_noches_avg_ntm'], bins=intervalosmna, labels=categoriasmna)
data['máximas_noches_avg_ntm']
# Out:
# 0            1 a 142.6
# 1        142.6 a 284.2
# 2       992.2 a 1125-0
# 3       992.2 a 1125-0
# 4       992.2 a 1125-0
#              ...
# 9442     284.2 a 425.8
# 9443     284.2 a 425.8
# 9444         1 a 142.6
# 9445     284.2 a 425.8
# 9446     284.2 a 425.8
# Name: máximas_noches_avg_ntm, Length: 9447, dtype: category
# Categories (8, object): ['1 a 142.6' < '142.6 a 284.2' < '284.2 a 425.8' < '425.8 a 567.4' < '567.4 a 709' < '709 a 850.6' < '850.6 a 992.2' < '992.2 a 1125-0']

# %%
tablemna= freq_tbl(data["máximas_noches_avg_ntm"])
tablemna1= tablemna.drop(["cumulative_perc"], axis=1)
tablemna2= tablemna1.set_index("máximas_noches_avg_ntm")
filtromna=tablemna2[tablemna2['frequency']>500]
filtromna
# Out:
#                         frequency  percentage
# máximas_noches_avg_ntm
# 992.2 a 1125-0               3585    0.379486
# 284.2 a 425.8                3300    0.349317
# 1 a 142.6                    1965    0.208003

# %%
filtromna.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('máximas_noches_avg_ntm de Valencia')
plt.xlabel('Promedio')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# availability_365

# %%
MaxA=data['disponibilidad_365'].max()
MinA=data['disponibilidad_365'].min()
LimitesA =[MinA,MaxA]
LimitesA
# Out:
# [0, 365]

# %%
RangoA=MaxA-MinA
RangoA
# Out:
# 365

# %%
i=RangoA/ni
i
# Out:
# 54.96507492157549

# %%
intervalosA=np.linspace(MinA,MaxA,16)
intervalosA
# Out:
# array([  0.        ,  24.33333333,  48.66666667,  73.        ,
#         97.33333333, 121.66666667, 146.        , 170.33333333,
#        194.66666667, 219.        , 243.33333333, 267.66666667,
#        292.        , 316.33333333, 340.66666667, 365.        ])

# %%
categoriasA = ["0 a 24.33", "24.33 a 48.67", "48.67 a 73", "73 a 97.33", "97.33 a 121.67", "121.67 a 146", "146 a 170.33", "170.33 a 194.67", "194.67 a 219", "219 a 243.33", "243.33 a 267.67", "267.67 a 292", "292 a 316.33", "316.33 a 340.67", "340.67 a 365"]
data['disponibilidad_365']=pd.cut(x=data['disponibilidad_365'], bins=intervalosA, labels=categoriasA)
data['disponibilidad_365']
# Out:
# 0          146 a 170.33
# 1            73 a 97.33
# 2          292 a 316.33
# 3            73 a 97.33
# 4          267.67 a 292
#              ...
# 9442       340.67 a 365
# 9443    316.33 a 340.67
# 9444          0 a 24.33
# 9445       267.67 a 292
# 9446       267.67 a 292
# Name: disponibilidad_365, Length: 9447, dtype: category
# Categories (15, object): ['0 a 24.33' < '24.33 a 48.67' < '48.67 a 73' < '73 a 97.33' ... '267.67 a 292' < '292 a 316.33' < '316.33 a 340.67' < '340.67 a 365']

# %%
tableA= freq_tbl(data["disponibilidad_365"])
tableA1= tableA.drop(["cumulative_perc"], axis=1)
tableA2= tableA1.set_index("disponibilidad_365")
filtroA=tableA2[tableA2['frequency']>500]
filtroA
# Out:
#                     frequency  percentage
# disponibilidad_365
# 340.67 a 365              995    0.105324
# 316.33 a 340.67           810    0.085742
# 48.67 a 73                749    0.079284
# 73 a 97.33                653    0.069122
# 24.33 a 48.67             652    0.069017
# 0 a 24.33                 643    0.068064
# 121.67 a 146              618    0.065418
# 146 a 170.33              557    0.058961
# 243.33 a 267.67           514    0.054409

# %%
filtroA.plot(kind = 'bar', width=0.8, figsize=(10,4), color="green")
plt.title('Disponibilidad en 365 días en Valencia')
plt.xlabel('Días')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# number_of_reviews

# %%
Maxnr=data['número_de_reseñas'].max()
Minnr=data['número_de_reseñas'].min()
Limitesnr =[Minnr,Maxnr]
Limitesnr
# Out:
# [0.0, 122.0]

# %%
Rangonr=Maxnr-Minnr
inr=Rangonr/ni
intervalosnr=np.linspace(Minnr,Maxnr,16)
intervalosnr
# Out:
# array([  0.        ,   8.13333333,  16.26666667,  24.4       ,
#         32.53333333,  40.66666667,  48.8       ,  56.93333333,
#         65.06666667,  73.2       ,  81.33333333,  89.46666667,
#         97.6       , 105.73333333, 113.86666667, 122.        ])

# %%
data["número_de_reseñas"].isnull().sum()
# Out:
# 0

# %%
categoriasnr = ["0 a 13", "13 a 26", "26 a 39", "39 a 52", "52 a 65", "65 a 78", "78 a 91", "91 a 104", "104 a 117", "117 a 130", "130 a 143", "143 a 156", "156 a 169", "169 a 182", "182 a 195"]
data['número_de_reseñas']=pd.cut(x=data['número_de_reseñas'], bins=intervalosnr, labels=categoriasnr)
data['número_de_reseñas']
# Out:
# 0       26 a 39
# 1        0 a 13
# 2       26 a 39
# 3       26 a 39
# 4       26 a 39
#          ...
# 9442        NaN
# 9443        NaN
# 9444        NaN
# 9445        NaN
# 9446        NaN
# Name: número_de_reseñas, Length: 9447, dtype: category
# Categories (15, object): ['0 a 13' < '13 a 26' < '26 a 39' < '39 a 52' ... '143 a 156' < '156 a 169' < '169 a 182' < '182 a 195']

# %%
tablenr= freq_tbl(data["número_de_reseñas"])
tablenr1= tablenr.drop(["cumulative_perc"], axis=1)
tablenr2= tablenr1.set_index("número_de_reseñas")
filtronr=tablenr2[tablenr2['frequency']>500]
filtronr
# Out:
#                    frequency  percentage
# número_de_reseñas
# 0 a 13                  2520    0.266751
# 26 a 39                 1770    0.187361
# 13 a 26                 1104    0.116862
# 39 a 52                  537    0.056843

# %%
filtronr.plot(kind = 'bar', width=0.8, figsize=(10,4), color="black")
plt.title('Número de críticas de Valencia')
plt.xlabel('Críticas')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# review_scores_value

# %%
Maxrsv=data['review_scores_value'].max()
Minrsv=data['review_scores_value'].min()
Limitesrsv =[Minrsv,Maxrsv]
Limitesrsv
# Out:
# [3.17, 5.0]

# %%
Rangorsv=Maxrsv-Minrsv
Rangorsv
# Out:
# 1.83

# %%
irsv=Rangorsv/ni
irsv
# Out:
# 0.27557832083967987

# %%
intervalosrsv=np.linspace(Minrsv,Maxrsv,16)
intervalosrsv
# Out:
# array([3.17 , 3.292, 3.414, 3.536, 3.658, 3.78 , 3.902, 4.024, 4.146,
#        4.268, 4.39 , 4.512, 4.634, 4.756, 4.878, 5.   ])

# %%
categoriasrsv = ["3.43 a 3.53", "3.53 a 3.64", "3.64 a 3.74", "3.74 a 3.85", "3.85 a 3.95", "3.95 a 4.06", "4.06 a 4.16", "4.16 a 4.27", "4.27 a 4.37", "4.37 a 4.48", "4.48 a 4.58", "4.58 a 4.69", "4.69 a 4.79", "4.79 a 4.90", "4.90 a 5"]
data['review_scores_value']=pd.cut(x=data['review_scores_value'], bins=intervalosrsv, labels=categoriasrsv)
data['review_scores_value']
# Out:
# 0       4.58 a 4.69
# 1       4.06 a 4.16
# 2       4.58 a 4.69
# 3       4.79 a 4.90
# 4       4.48 a 4.58
#            ...
# 9442    4.58 a 4.69
# 9443    4.58 a 4.69
# 9444    4.58 a 4.69
# 9445    4.58 a 4.69
# 9446    4.58 a 4.69
# Name: review_scores_value, Length: 9447, dtype: category
# Categories (15, object): ['3.43 a 3.53' < '3.53 a 3.64' < '3.64 a 3.74' < '3.74 a 3.85' ... '4.58 a 4.69' < '4.69 a 4.79' < '4.79 a 4.90' < '4.90 a 5']

# %%
tablersv= freq_tbl(data["review_scores_value"])
tablersv1= tablersv.drop(["cumulative_perc"], axis=1)
tablersv2= tablersv1.set_index("review_scores_value")
filtrorsv=tablersv2[tablersv2['frequency']>500]
filtrorsv
# Out:
#                      frequency  percentage
# review_scores_value
# 4.58 a 4.69               2642    0.279666
# 4.69 a 4.79               1548    0.163862
# 4.90 a 5                  1430    0.151371
# 4.79 a 4.90               1296    0.137186
# 4.48 a 4.58                895    0.094739
# 4.37 a 4.48                549    0.058114

# %%
filtrorsv.plot(kind = 'bar', width=0.8, figsize=(10,4), color="green")
plt.title("Puntuaciones de Valencia")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrpm=data['reseñas_por_mes'].max()
Minrpm=data['reseñas_por_mes'].min()
Limitesrpm =[Minrpm,Maxrpm]
Limitesrpm
# Out:
# ['--', '9.49']

# %%
Maxrsch=data['review_scores_checkin'].max()
Minrsch=data['review_scores_checkin'].min()
Limitesrsch =[Minrsch,Maxrsch]
Limitesrsch
# Out:
# [3.86, 5.0]

# %%
Rangorsch=Maxrsch-Minrsch
Rangorsch
# Out:
# 1.1400000000000001

# %%
irsch=Rangorsch/ni
irsch
# Out:
# 0.17167174085094813

# %%
intervalosrsch=np.linspace(Minrsch,Maxrsch,16)
intervalosrsch
# Out:
# array([3.86 , 3.936, 4.012, 4.088, 4.164, 4.24 , 4.316, 4.392, 4.468,
#        4.544, 4.62 , 4.696, 4.772, 4.848, 4.924, 5.   ])

# %%
categoriasrsch = ["3.93 a 4.00", "4.00 a 4.07", "4.07 a 4.14", "4.14 a 4.22", "4.22 a 4.29", "4.29 a 4.36", "4.36 a 4.43", "4.43 a 4.50", "4.50 a 4.57", "4.57 a 4.64", "4.64 a 4.71", "4.71 a 4.79", "4.79 a 4.86", "4.86 a 4.93", "4.93 a 5"]
data['review_scores_checkin']=pd.cut(x=data['review_scores_checkin'], bins=intervalosrsch, labels=categoriasrsch)
data['review_scores_checkin']
# Out:
# 0       4.79 a 4.86
# 1          4.93 a 5
# 2       4.79 a 4.86
# 3       4.86 a 4.93
# 4       4.71 a 4.79
#            ...
# 9442    4.79 a 4.86
# 9443    4.79 a 4.86
# 9444    4.79 a 4.86
# 9445    4.79 a 4.86
# 9446    4.79 a 4.86
# Name: review_scores_checkin, Length: 9447, dtype: category
# Categories (15, object): ['3.93 a 4.00' < '4.00 a 4.07' < '4.07 a 4.14' < '4.14 a 4.22' ... '4.71 a 4.79' < '4.79 a 4.86' < '4.86 a 4.93' < '4.93 a 5']

# %%
tablersch= freq_tbl(data["review_scores_checkin"])
tablersch1= tablersch.drop(["cumulative_perc"], axis=1)
tablersch2= tablersch1.set_index("review_scores_checkin")
filtrorsch=tablersch2[tablersch2['frequency']>500]
filtrorsch
# Out:
#                        frequency  percentage
# review_scores_checkin
# 4.93 a 5                    2998    0.317349
# 4.79 a 4.86                 2610    0.276278
# 4.86 a 4.93                 1574    0.166614
# 4.71 a 4.79                  757    0.080131

# %%
filtrorsch.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title("Puntuaciones de check-in")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# cleanless

# %%
Maxrscl=data['review_scores_cleanliness'].max()
Minrscl=data['review_scores_cleanliness'].min()
Limitesrscl =[Minrscl,Maxrscl]
Limitesrscl
# Out:
# [3.33, 5.0]

# %%
Rangorscl=Maxrscl-Minrscl
Rangorscl
# Out:
# 1.67

# %%
irscl=Rangorscl/ni
irscl
# Out:
# 0.2514840414220029

# %%
intervalosrscl=np.linspace(Minrscl,Maxrscl,16)
intervalosrscl
# Out:
# array([3.33      , 3.44133333, 3.55266667, 3.664     , 3.77533333,
#        3.88666667, 3.998     , 4.10933333, 4.22066667, 4.332     ,
#        4.44333333, 4.55466667, 4.666     , 4.77733333, 4.88866667,
#        5.        ])

# %%
categoriasrscl = ["3.59 a 3.68", "3.68 a 3.78", "3.78 a 3.87", "3.87 a 3.97", "3.97 a 4.06", "4.06 a 4.15", "4.15 a 4.25", "4.25 a 4.34", "4.34 a 4.44", "4.44 a 4.53", "4.53 a 4.62", "4.62 a 4.72", "4.72 a 4.81", "4.81 a 4.91", "4.91 a 5"]
data['review_scores_cleanliness']=pd.cut(x=data['review_scores_cleanliness'], bins=intervalosrscl, labels=categoriasrscl)
data['review_scores_cleanliness']
# Out:
# 0       4.62 a 4.72
# 1          4.91 a 5
# 2       4.53 a 4.62
# 3       4.81 a 4.91
# 4       4.44 a 4.53
#            ...
# 9442    4.72 a 4.81
# 9443    4.72 a 4.81
# 9444    4.72 a 4.81
# 9445    4.72 a 4.81
# 9446    4.72 a 4.81
# Name: review_scores_cleanliness, Length: 9447, dtype: category
# Categories (15, object): ['3.59 a 3.68' < '3.68 a 3.78' < '3.78 a 3.87' < '3.87 a 3.97' ... '4.62 a 4.72' < '4.72 a 4.81' < '4.81 a 4.91' < '4.91 a 5']

# %%
tablerscl= freq_tbl(data["review_scores_cleanliness"])
tablerscl1= tablerscl.drop(["cumulative_perc"], axis=1)
tablerscl2= tablerscl1.set_index("review_scores_cleanliness")
filtrorscl=tablerscl2[tablerscl2['frequency']>500]
filtrorscl
# Out:
#                            frequency  percentage
# review_scores_cleanliness
# 4.72 a 4.81                     2810    0.297449
# 4.91 a 5                        2478    0.262305
# 4.81 a 4.91                     1374    0.145443
# 4.62 a 4.72                      751    0.079496
# 4.53 a 4.62                      633    0.067005

# %%
filtrorscl.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title("Limpieza en Valencia")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsa=data['review_scores_accuracy'].max()
Minrsa=data['review_scores_accuracy'].min()
Limitesrsa =[Minrsa,Maxrsa]
Limitesrsa
# Out:
# [3.67, 5.0]

# %%
Rangorsa=Maxrsa-Minrsa
irsa=Rangorsa/ni
intervalosrsa=np.linspace(Minrsa,Maxrsa,16)
intervalosrsa
# Out:
# array([3.67      , 3.75866667, 3.84733333, 3.936     , 4.02466667,
#        4.11333333, 4.202     , 4.29066667, 4.37933333, 4.468     ,
#        4.55666667, 4.64533333, 4.734     , 4.82266667, 4.91133333,
#        5.        ])

# %%
tablersa= freq_tbl(data["review_scores_accuracy"])
tablersa1= tablersa.drop(["cumulative_perc"], axis=1)
tablersa2= tablersa1.set_index("review_scores_accuracy")
filtrorsa=tablersa2[tablersa2['frequency']>500]
filtrorsa
# Out:
#                         frequency  percentage
# review_scores_accuracy
# 4.76 a 4.84                  2823    0.298825
# 4.92 a 5                     2291    0.242511
# 4.84 a 4.92                  1509    0.159733
# 4.68 a 4.76                   918    0.097174
# 4.60 a 4.68                   581    0.061501

# %%
filtrorsa.plot(kind = 'bar', width=0.8, figsize=(10,4), color="yellow")
plt.title("Exactitud en Valencia")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
