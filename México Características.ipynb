# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
lectura= pd.read_csv("México por IQR.csv")

# %%
lectura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26582 non-null  int64
#  1   id                                            26582 non-null  int64
#  2   source                                        26582 non-null  object
#  3   name                                          26582 non-null  object
#  4   description                                   26582 non-null  object
#  5   neighborhood_overview                         26582 non-null  object
#  6   host_id                                       26582 non-null  int64
#  7   host_name                                     26582 non-null  object
#  8   host_response_time                            26582 non-null  object
# ...

# %%
lectura.head()
n=26582

# %%
freq_tbl(lectura)
# Out:
#             source  frequency  percentage  cumulative_perc
# 0      city scrape      23671     0.89049          0.89049
# 1  previous scrape       2911     0.10951          1.00000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0         Blueground | Roma Sur 1 recamara, AC & rooftop         57
# 1                          Blueground | Polanco, parking         49
# 2                        Perfecto Loft en gran ubicación         48
# 3      Blueground | Amueblado, Security & Business Ce...         36
# 4                                       Magenta by Kukun         21
# ...                                                  ...        ...
# 25165      Astonishing view@Condesa best nbh perfect apt          1
# 25166  Private suite in Condesa Great internet & loca...          1
# 25167          Artsy habitación frente al Parque México!          1
# ...

# %%
table1= freq_tbl(lectura['source'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_indexa= filtro.set_index('source')
filtro_indexa
# Out:
#                  frequency
# source
# city scrape          23671
# previous scrape       2911

# %%
filtro_indexa.plot(kind = 'bar', width=0.8, figsize=(10,4), color="skyblue")
plt.title('Fuente de búsqueda en México')
plt.xlabel('Source')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table1= freq_tbl(lectura['host_response_time'])
table2= table1.drop(['percentage', 'cumulative_perc'], axis=1)
filtro=table2[table2['frequency']>1]
filtro_index= filtro.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour          18792
# Unknown                  3622
# within a few hours       1957
# a few days or more       1108
# within a day             1103

# %%
filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Tiempo de respuesta del host en México')
# Out:
# Text(0.5, 1.0, 'Tiempo de respuesta del host en México')

# %%
tablehis= freq_tbl(lectura["host_is_superhost"])
tablehis1= tablehis.drop(["cumulative_perc"], axis=1)
tablehis2= tablehis1.set_index("host_is_superhost")
tablehis2
# Out:
#                    frequency  percentage
# host_is_superhost
# f                      16268    0.611993
# t                      10314    0.388007

# %%
tablehis2["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Host es superhost en México')
# Out:
# Text(0.5, 1.0, 'Host es superhost en México')

# %%
tablengc= freq_tbl(lectura["neighbourhood_group_cleansed"])
tablengc1= tablengc.drop(["cumulative_perc"], axis=1)
tablengc2= tablengc1.set_index("neighbourhood_group_cleansed")
filtrongc=tablengc2[tablengc2['frequency']>100]
filtrongc
# Out:
#                               frequency  percentage
# neighbourhood_group_cleansed
# No especificado                   26582         1.0

# %%
filtrongc.plot(kind = 'bar', width=1, figsize=(10,4), color="green")
plt.title('Vecindarios seleccionados importantes en México')
plt.xlabel('Vecindarios')
plt.ylabel("Frecuencia de vecindarios")
# Out:
# Text(0, 0.5, 'Frecuencia de vecindarios')

# %%
tablenc= freq_tbl(lectura["neighbourhood_cleansed"])
tablenc1= tablenc.drop(["cumulative_perc"], axis=1)
tablenc2= tablenc1.set_index("neighbourhood_cleansed")
filtronc=tablenc2[tablenc2['frequency']>500]
filtronc
# Out:
#                         frequency  percentage
# neighbourhood_cleansed
# Cuauhtémoc                  12231    0.460123
# Miguel Hidalgo               4533    0.170529
# Benito Juárez                3152    0.118576
# Coyoacán                     1719    0.064668
# Álvaro Obregón               1075    0.040441
# Tlalpan                       812    0.030547
# Venustiano Carranza           734    0.027613
# Gustavo A. Madero             506    0.019035

# %%
filtronc.plot(kind = 'bar', width=1, figsize=(10,4), color="YELLOW")
plt.title('Vecindarios importantes en México')
plt.xlabel('Vecindarios')
plt.ylabel("Frecuencia de vecindarios")
# Out:
# Text(0, 0.5, 'Frecuencia de vecindarios')

# %%
tablert= freq_tbl(lectura["room_type"])
tablert1= tablert.drop(["cumulative_perc"], axis=1)
tablert2= tablert1.set_index("room_type")
tablert2
# Out:
#                  frequency  percentage
# room_type
# Entire home/apt      17363    0.653186
# Private room          8693    0.327026
# Shared room            401    0.015085
# Hotel room             125    0.004702

# %%
tablert2.plot(kind = 'bar', width=1, figsize=(10,4), color="red")
plt.title('Tipo de habitación en México')
plt.xlabel('Habitación')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tableib= freq_tbl(lectura["instant_bookable"])
tableib1= tableib.drop(["cumulative_perc"], axis=1)
tableib2= tableib1.set_index("instant_bookable")
tableib2
# Out:
#                   frequency  percentage
# instant_bookable
# f                     16080    0.604921
# t                     10502    0.395079

# %%
tableib2["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Reservación instantanea en México')
# Out:
# Text(0.5, 1.0, 'Reservación instantanea en México')

# %%
tablept= freq_tbl(lectura["property_type"])
tablept1= tablept.drop(["cumulative_perc"], axis=1)
tablept2= tablept1.set_index("property_type")
filtropt=tablept2[tablept2['frequency']>300]
filtropt
# Out:
#                              frequency  percentage
# property_type
# Entire rental unit                9971    0.375103
# Entire condo                      3423    0.128771
# Private room in rental unit       3034    0.114137
# Private room in home              2266    0.085246
# Entire loft                       1515    0.056993
# Private room in condo              846    0.031826
# Entire serviced apartment          846    0.031826
# Entire home                        817    0.030735
# Room in hotel                      504    0.018960
# Private room in guesthouse         381    0.014333

# %%
filtropt.plot(kind = 'bar', width=1, figsize=(10,4), color="brown")
plt.title('Tipo de propiedad en México')
plt.xlabel('Propiedad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tableha= freq_tbl(lectura["has_availability"])
tableha1= tableha.drop(["cumulative_perc"], axis=1)
tableha2= tableha1.set_index("has_availability")
filtroha=tableha2[tableha2['frequency']>3]
filtroha
# Out:
#                   frequency  percentage
# has_availability
# t                     26541    0.998458
# f                        41    0.001542

# %%
filtroha.plot(kind = 'bar', width=1, figsize=(10,4), color="brown")
plt.title('Disponibilidad actual en México')
plt.xlabel('Está disponible')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tableac = lectura['accommodates'].value_counts().reset_index()
tableac.columns = ['accommodates', 'frequency']
filtro = tableac[tableac['frequency'] >9]
filtroac = filtro.set_index('accommodates')
filtroac
# Out:
#               frequency
# accommodates
# 2.0               10620
# 4.0                5690
# 3.0                3753
# 1.0                3033
# 6.0                1800
# 5.0                1375
# 7.0                 311

# %%
filtroac.plot(kind = 'bar', width=0.8, figsize=(10,4), color="brown")
plt.title('Capacidad de personas en México')
plt.xlabel('Personas')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablebr = lectura['bathrooms'].value_counts().reset_index()
tablebr.columns = ['bathrooms', 'frequency']
filtro = tablebr[tablebr['frequency'] >100]
filtrobr = filtro.set_index('bathrooms')
filtrobr
# Out:
#            frequency
# bathrooms
# 1.0            18641
# 2.0             4462
# 1.5             1657
# 2.5              836
# 3.0              585
# 3.5              242

# %%
filtrobr["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Baños en México')
# Out:
# Text(0.5, 1.0, 'Baños en México')

# %%
tablebe = lectura['bedrooms'].value_counts().reset_index()
tablebe.columns = ['bedrooms', 'frequency']
filtro = tablebe[tablebe['frequency'] >0]
filtrobe = filtro.set_index('bedrooms')
filtrobe
# Out:
#           frequency
# bedrooms
# 1.0           17162
# 2.0            7018
# 3.0            1939
# 0.0             463

# %%
filtrobe["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Habitaciones en México')
# Out:
# Text(0.5, 1.0, 'Habitaciones en México')

# %%
tablebs = lectura['beds'].value_counts().reset_index()
tablebs.columns = ['beds', 'frequency']
filtro = tablebs[tablebs['frequency'] >0]
filtrobs = filtro.set_index('beds')
filtrobs
# Out:
#       frequency
# beds
# 2.0       11867
# 1.0       11409
# 3.0        2834
# 0.0         472

# %%
filtrobs.plot(kind = 'bar', width=0.8, figsize=(10,4), color="brown")
plt.title('Camas en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tableminn = lectura['minimum_nights'].value_counts().reset_index()
tableminn.columns = ['minimum_nights', 'frequency']
filtro = tableminn[tableminn['frequency'] >0]
filtrominn = filtro.set_index('minimum_nights')
filtrominn
# Out:
#                 frequency
# minimum_nights
# 1.0                 12621
# 2.0                 11055
# 3.0                  2906

# %%
filtrobs.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title('Noches mínimas en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablechlc = lectura['calculated_host_listings_count'].value_counts().reset_index()
tablechlc.columns = ['calculated_host_listings_count', 'frequency']
filtro = tablechlc[tablechlc['frequency'] >500]
filtrochlc = filtro.set_index('calculated_host_listings_count')
filtrochlc
# Out:
#                                 frequency
# calculated_host_listings_count
# 1.0                                  8440
# 5.0                                  4718
# 2.0                                  3316
# 3.0                                  1971
# 4.0                                  1460
# 7.0                                   861
# 6.0                                   852
# 8.0                                   672

# %%
filtrochlc.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title('Recuento calculado de listados de anfitriones en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablechlceh = lectura['calculated_host_listings_count_entire_homes'].value_counts().reset_index()
tablechlceh.columns = ['calculated_host_listings_count_entire_homes', 'frequency']
filtro = tablechlceh[tablechlceh['frequency'] >400]
filtrochlceh = filtro.set_index('calculated_host_listings_count_entire_homes')
filtrochlceh
# Out:
#                                              frequency
# calculated_host_listings_count_entire_homes
# 1.0                                               7341
# 0.0                                               6791
# 2.0                                               6201
# 3.0                                               1218
# 4.0                                               1017
# 5.0                                                718
# 6.0                                                518

# %%
filtrochlceh.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title('Recuento calculado de listados de casas enteras de anfitriones en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablechlcsr = lectura['calculated_host_listings_count_shared_rooms'].value_counts().reset_index()
tablechlcsr.columns = ['calculated_host_listings_count_shared_rooms', 'frequency']
filtro = tablechlcsr[tablechlcsr['frequency'] >500]
filtrochlcsr = filtro.set_index('calculated_host_listings_count_shared_rooms')
filtrochlcsr
# Out:
#                                              frequency
# calculated_host_listings_count_shared_rooms
# 0.0                                              26582

# %%
filtrochlcsr["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Recuento calculado de listados de habitaciones compartidas de anfitriones en México')
# Out:
# Text(0.5, 1.0, 'Recuento calculado de listados de habitaciones compartidas de anfitriones en México')

# %%
tablechlcpr = lectura['calculated_host_listings_count_private_rooms'].value_counts().reset_index()
tablechlcpr.columns = ['calculated_host_listings_count_private_rooms', 'frequency']
filtro = tablechlcpr[tablechlcpr['frequency'] >500]
filtrochlcpr = filtro.set_index('calculated_host_listings_count_private_rooms')
filtrochlcpr
# Out:
#                                               frequency
# calculated_host_listings_count_private_rooms
# 0.0                                               15114
# 1.0                                                7101
# 2.0                                                1813
# 3.0                                                1039
# 4.0                                                 885
# 5.0                                                 630

# %%
filtrochlceh.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title('Recuento calculado de listados de habitaciones privadas de anfitriones en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablehid = lectura['host_id'].value_counts().reset_index()
tablehid.columns = ['host_id', 'frequency']
filtro = tablehid[tablehid['frequency'] > 100]
filtrohid = filtro.set_index('host_id')
filtrohid
# Out:
#            frequency
# host_id
# 498701635        258
# 10764020         216
# 333035396        177
# 539407308        170
# 16148871         148
# 207240505        115
# 91265490         109
# 245618000        103

# %%
filtrohid.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title('ID de los hosts con más alojamientos en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tablehn= freq_tbl(lectura["host_name"])
tablehn1= tablehn.drop(["cumulative_perc"], axis=1)
tablehn2= tablehn1.set_index("host_name")
filtrohn=tablehn2[tablehn2['frequency']>200]
filtrohn
# Out:
#             frequency  percentage
# host_name
# Alejandra         341    0.012828
# Alejandro         293    0.011022
# Luis              292    0.010985
# Virtual           287    0.010797
# Blueground        258    0.009706
# Mr. W             243    0.009142
# Juan              239    0.008991
# Jorge             223    0.008389
# Carlos            222    0.008352

# %%
filtrohn.plot(kind = 'bar', width=0.8, figsize=(10,4), color="grey")
plt.title('Nombres más comunes de los hosts en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **4. Categorización de las variables**

# %%
lectura['host_response_rate'] = lectura['host_response_rate'].str.rstrip('%').astype(float)

# %%
Max=lectura['host_response_rate'].max()
Min=lectura['host_response_rate'].min()
Limites =[Min,Max]
Limites
# Out:
# [0.0, 100.0]

# %%
Rango=Max-Min
Rango
# Out:
# 100.0

# %%
ni= 1 + 3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
i=Rango/ni
i
# Out:
# 6.373636189094067

# %%
intervalos=np.linspace(Min,Max,16)
intervalos
# Out:
# array([  0.        ,   6.66666667,  13.33333333,  20.        ,
#         26.66666667,  33.33333333,  40.        ,  46.66666667,
#         53.33333333,  60.        ,  66.66666667,  73.33333333,
#         80.        ,  86.66666667,  93.33333333, 100.        ])

# %%
categorias= ["0 a 6.66", "6.66 a 13.33", "13.33 a 20", "20 a 26.66", "26.66 a 33.33", "33.33 a 40", "40 a 46.66" , "46.66 a 53.33", "53.33 a 60", "60 a 66.66", "66.66 a 73.33", "73.33 a 80", "80 a 86.66", "86.66 a 93.33", "93.33 a 100"]
lectura['host_response_rate']=pd.cut(x=lectura['host_response_rate'], bins=intervalos, labels=categorias)
lectura['host_response_rate']
# Out:
# 0                  NaN
# 1          93.33 a 100
# 2        66.66 a 73.33
# 3          93.33 a 100
# 4          93.33 a 100
#              ...
# 26577      93.33 a 100
# 26578      93.33 a 100
# 26579      93.33 a 100
# 26580      93.33 a 100
# 26581      93.33 a 100
# Name: host_response_rate, Length: 26582, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
table1= freq_tbl(lectura["host_response_rate"])
table1a= table1.drop(["cumulative_perc"], axis=1)
table1b= table1a.set_index("host_response_rate")
filtro=table1b[table1b['frequency']>50]
filtro
# Out:
#                     frequency  percentage
# host_response_rate
# 93.33 a 100             23253    0.874765
# 86.66 a 93.33            1100    0.041381
# 0 a 6.66                  683    0.025694
# 73.33 a 80                369    0.013882
# 66.66 a 73.33             236    0.008878
# 46.66 a 53.33             220    0.008276
# 80 a 86.66                196    0.007373
# 26.66 a 33.33             124    0.004665
# 53.33 a 60                108    0.004063
# 13.33 a 20                 79    0.002972
# 6.66 a 13.33               69    0.002596
# 33.33 a 40                 68    0.002558

# %%
filtro.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Tasa de respuesta de host en México')
plt.xlabel('Porcentajes')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
lectura['host_acceptance_rate'] = lectura['host_acceptance_rate'].str.rstrip('%').astype(float)

# %%
Maxhar=lectura['host_acceptance_rate'].max()
Minhar=lectura['host_acceptance_rate'].min()
Limites =[Minhar,Maxhar]
Limites
# Out:
# [0.0, 100.0]

# %%
Rango=Maxhar-Minhar
Rango
# Out:
# 100.0

# %%
iHar=Rango/ni
iHar
# Out:
# 6.373636189094067

# %%
intervaloshar=np.linspace(Minhar,Maxhar,16)
intervaloshar
# Out:
# array([  0.        ,   6.66666667,  13.33333333,  20.        ,
#         26.66666667,  33.33333333,  40.        ,  46.66666667,
#         53.33333333,  60.        ,  66.66666667,  73.33333333,
#         80.        ,  86.66666667,  93.33333333, 100.        ])

# %%
categoriashar= ["0 a 6.66", "6.66 a 13.33", "13.33 a 20", "20 a 26.66", "26.66 a 33.33", "33.33 a 40", "40 a 46.66" , "46.66 a 53.33", "53.33 a 60", "60 a 66.66", "66.66 a 73.33", "73.33 a 80", "80 a 86.66", "86.66 a 93.33", "93.33 a 100"]
lectura['host_acceptance_rate']=pd.cut(x=lectura['host_acceptance_rate'], bins=intervaloshar, labels=categoriashar)
lectura['host_acceptance_rate']
# Out:
# 0          93.33 a 100
# 1        86.66 a 93.33
# 2           53.33 a 60
# 3          93.33 a 100
# 4          93.33 a 100
#              ...
# 26577      93.33 a 100
# 26578      93.33 a 100
# 26579      93.33 a 100
# 26580      93.33 a 100
# 26581      93.33 a 100
# Name: host_acceptance_rate, Length: 26582, dtype: category
# Categories (15, object): ['0 a 6.66' < '6.66 a 13.33' < '13.33 a 20' < '20 a 26.66' ... '73.33 a 80' < '80 a 86.66' < '86.66 a 93.33' < '93.33 a 100']

# %%
tablehar= freq_tbl(lectura["host_acceptance_rate"])
tablehar1= tablehar.drop(["cumulative_perc"], axis=1)
tablehar2= tablehar1.set_index("host_acceptance_rate")
filtrohar=tablehar2[tablehar2['frequency']>150]
filtrohar
# Out:
#                       frequency  percentage
# host_acceptance_rate
# 93.33 a 100               21816    0.820706
# 86.66 a 93.33              1431    0.053833
# 80 a 86.66                  750    0.028215
# 73.33 a 80                  581    0.021857
# 66.66 a 73.33               501    0.018847
# 46.66 a 53.33               356    0.013393
# 26.66 a 33.33               311    0.011700
# 53.33 a 60                  198    0.007449

# %%
filtrohar.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Tasa de aceptación del host en México')
plt.xlabel('Porcentajes')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxac=lectura['accommodates'].max()
Minac=lectura['accommodates'].min()
Limitesac =[Minac,Maxac]
Limitesac
# Out:
# [1.0, 7.0]

# %%
Rango=Maxac-Minac
Rango
# Out:
# 6.0

# %%
i=Rango/ni
i
# Out:
# 0.38241817134564404

# %%
intervalosac=np.linspace(Minac,Maxac,16)
intervalosac
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. , 5.4, 5.8,
#        6.2, 6.6, 7. ])

# %%
categoriasac = ["1 a 1.4", "1.4 a 1.8", "1.8 a 2.2", "2.2 a 2.6", "2.6 a 3", "3 a 3.4", "3.4 a 3.8", "3.8 a 4.2", "4.2 a 4.6", "4.6 a 5", "5 a 5.4", "5.4 a 5.8", "5.8 a 6.2", "6.2 a 6.6", "6.6 a 7"]
lectura['accommodates']=pd.cut(x=lectura['accommodates'], bins=intervalosac, labels=categoriasac)
lectura['accommodates']
# Out:
# 0        1.8 a 2.2
# 1          2.6 a 3
# 2        3.8 a 4.2
# 3        1.8 a 2.2
# 4        1.8 a 2.2
#            ...
# 26577    3.8 a 4.2
# 26578    1.8 a 2.2
# 26579    1.8 a 2.2
# 26580    1.8 a 2.2
# 26581    1.8 a 2.2
# Name: accommodates, Length: 26582, dtype: category
# Categories (15, object): ['1 a 1.4' < '1.4 a 1.8' < '1.8 a 2.2' < '2.2 a 2.6' ... '5.4 a 5.8' < '5.8 a 6.2' < '6.2 a 6.6' < '6.6 a 7']

# %%
tableac= freq_tbl(lectura["accommodates"])
tableac1= tableac.drop(["cumulative_perc"], axis=1)
tableac2= tableac1.set_index("accommodates")
filtroac=tableac2[tableac2['frequency']>150]
filtroac
# Out:
#               frequency  percentage
# accommodates
# 1.8 a 2.2         13653    0.513618
# 3.8 a 4.2          5690    0.214055
# 2.6 a 3            3753    0.141186
# 5.8 a 6.2          1800    0.067715
# 4.6 a 5            1375    0.051727
# 6.6 a 7             311    0.011700

# %%
filtroac.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Capacidad de personas en Airbnb México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxbd=lectura['beds'].max()
Minbd=lectura['beds'].min()
Limitesbd =[Minbd,Maxbd]
Limitesbd
# Out:
# [0.0, 3.0]

# %%
Rangobd=Maxbd-Minbd
Rangobd
# Out:
# 3.0

# %%
i=Rangobd/ni
i
# Out:
# 0.19120908567282202

# %%
intervalosbd=np.linspace(Minbd,Maxbd,16)
intervalosbd
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. ])

# %%
categoriasbd = ["0 a 0.2", "0.2 a 0.4", "0.4 a 0.6", "0.6 a 0.8", "0.8 a 1", "1 a 1.2", "1.2 a 1.4", "1.4 a 1.6", "1.6 a 1.8", "1.8 a 2", "2 a 2.2", "2.2 a 2.4", "2.4 a 2.6", "2.6 a 2.8", "2.8 a 3"]
lectura['beds']=pd.cut(x=lectura['beds'], bins=intervalosbd, labels=categoriasbd)
lectura['beds']
# Out:
# 0        0.8 a 1
# 1        1.8 a 2
# 2        1.8 a 2
# 3        0.8 a 1
# 4        0.8 a 1
#           ...
# 26577    1.8 a 2
# 26578    0.8 a 1
# 26579    0.8 a 1
# 26580    0.8 a 1
# 26581    0.8 a 1
# Name: beds, Length: 26582, dtype: category
# Categories (15, object): ['0 a 0.2' < '0.2 a 0.4' < '0.4 a 0.6' < '0.6 a 0.8' ... '2.2 a 2.4' < '2.4 a 2.6' < '2.6 a 2.8' < '2.8 a 3']

# %%
tablebd= freq_tbl(lectura["beds"])
tablebd1= tablebd.drop(["cumulative_perc"], axis=1)
tablebd2= tablebd1.set_index("beds")
filtrobd=tablebd2[tablebd2['frequency']>150]
filtrobd
# Out:
#          frequency  percentage
# beds
# 1.8 a 2      12339    0.464186
# 0.8 a 1      11409    0.429200
# 2.8 a 3       2834    0.106613

# %%
filtrobd.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Camas en México')
plt.xlabel('Cantidad')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
MaxP=lectura['price'].max()
MinP=lectura['price'].min()
LimitesP =[MinP,MaxP]
LimitesP
# Out:
# [0.0, 2977.0]

# %%
RangoP=MaxP-MinP
RangoP
# Out:
# 2977.0

# %%
iP=RangoP/ni
iP
# Out:
# 189.74314934933037

# %%
intervalosP=np.linspace(MinP,MaxP,16)
intervalosP
# Out:
# array([   0.        ,  198.46666667,  396.93333333,  595.4       ,
#         793.86666667,  992.33333333, 1190.8       , 1389.26666667,
#        1587.73333333, 1786.2       , 1984.66666667, 2183.13333333,
#        2381.6       , 2580.06666667, 2778.53333333, 2977.        ])

# %%
categoriasP = ["0 a 198.47", "198.47 a 396.93", "396.93 a 595.4", "595.4 a 793.87", "793.87 a 992.33", "992.33 a 1190.8", "1190.8 a 1389.27", "1389.27 a 1587.73", "1587.73 a 1786.2", "1786.2 a 1984.67", "1984.67 a 2183.13", "2183.13 a 2381.6", "2381.6 a 2580.07", "2580.07 a 2778.53", "2778.53 a 2977"]
lectura['price']=pd.cut(x=lectura['price'], bins=intervalosP, labels=categoriasP)
lectura['price']
# Out:
# 0          793.87 a 992.33
# 1                      NaN
# 2        1984.67 a 2183.13
# 3          992.33 a 1190.8
# 4          793.87 a 992.33
#                ...
# 26577       396.93 a 595.4
# 26578       2778.53 a 2977
# 26579    2580.07 a 2778.53
# 26580    2580.07 a 2778.53
# 26581     1190.8 a 1389.27
# Name: price, Length: 26582, dtype: category
# Categories (15, object): ['0 a 198.47' < '198.47 a 396.93' < '396.93 a 595.4' < '595.4 a 793.87' ... '2183.13 a 2381.6' < '2381.6 a 2580.07' < '2580.07 a 2778.53' < '2778.53 a 2977']

# %%
lectura['price'].isnull().sum()
# Out:
# 2928

# %%
lectura['price']=lectura['price'].fillna("793.87 a 992.33")

# %%
tableP= freq_tbl(lectura["price"])
tableP1= tableP.drop(["cumulative_perc"], axis=1)
tableP2= tableP1.set_index("price")
filtroP=tableP2[tableP2['frequency']>500]
filtroP
# Out:
#                    frequency  percentage
# price
# 793.87 a 992.33         7895    0.297005
# 396.93 a 595.4          3201    0.120420
# 595.4 a 793.87          3026    0.113836
# 992.33 a 1190.8         2516    0.094651
# 198.47 a 396.93         2186    0.082236
# 1190.8 a 1389.27        2106    0.079227
# 1389.27 a 1587.73       1527    0.057445
# 1587.73 a 1786.2         999    0.037582
# 1786.2 a 1984.67         844    0.031751
# 1984.67 a 2183.13        733    0.027575

# %%
filtroP.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Precios en México')
plt.xlabel('Precio')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxmna=lectura['maximum_nights_avg_ntm'].max()
Minmna=lectura['maximum_nights_avg_ntm'].min()
Limitesmna =[Minmna,Maxmna]
Limitesmna
# Out:
# [1.0, 1825.0]

# %%
Rangomna=Maxmna-Minmna
Rangomna
# Out:
# 1824.0

# %%
imna=Rangomna/ni
imna
# Out:
# 116.25512408907578

# %%
intervalosmna=np.linspace(Minmna,Maxmna,16)
intervalosmna
# Out:
# array([1.0000e+00, 1.2260e+02, 2.4420e+02, 3.6580e+02, 4.8740e+02,
#        6.0900e+02, 7.3060e+02, 8.5220e+02, 9.7380e+02, 1.0954e+03,
#        1.2170e+03, 1.3386e+03, 1.4602e+03, 1.5818e+03, 1.7034e+03,
#        1.8250e+03])

# %%
categoriasmna = ["1 a 122.6", "122.6 a 244.2", "244.2 a 365.8", "365.8 a 487.4", "487.4 a 609", "609 a 730.6", "730.6 a 852.2", "852.2 a 973.8", "973.8 a 1095.4", "1095.4 a 1217", "1217 a 1338.6", "1338.6 a 1460.2", "1460.2 a 1581.8", "1581.8 a 1703.4", "1703.4 a 1825"]
lectura['maximum_nights_avg_ntm']=pd.cut(x=lectura['maximum_nights_avg_ntm'], bins=intervalosmna, labels=categoriasmna)
lectura['maximum_nights_avg_ntm']
# Out:
# 0            1 a 122.6
# 1        244.2 a 365.8
# 2            1 a 122.6
# 3        122.6 a 244.2
# 4        1095.4 a 1217
#              ...
# 26577        1 a 122.6
# 26578    244.2 a 365.8
# 26579    244.2 a 365.8
# 26580    244.2 a 365.8
# 26581    244.2 a 365.8
# Name: maximum_nights_avg_ntm, Length: 26582, dtype: category
# Categories (15, object): ['1 a 122.6' < '122.6 a 244.2' < '244.2 a 365.8' < '365.8 a 487.4' ... '1338.6 a 1460.2' < '1460.2 a 1581.8' < '1581.8 a 1703.4' < '1703.4 a 1825']

# %%
lectura['maximum_nights_avg_ntm'].isnull().sum()
# Out:
# 13

# %%
tablemna= freq_tbl(lectura["maximum_nights_avg_ntm"])
tablemna1= tablemna.drop(["cumulative_perc"], axis=1)
tablemna2= tablemna1.set_index("maximum_nights_avg_ntm")
filtromna=tablemna2[tablemna2['frequency']>500]
filtromna
# Out:
#                         frequency  percentage
# maximum_nights_avg_ntm
# 1095.4 a 1217               14244    0.535851
# 244.2 a 365.8                7607    0.286171
# 1 a 122.6                    3462    0.130239

# %%
filtromna.plot(kind = 'bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Promedio de noches máximas en México')
plt.xlabel('Promedio')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
MaxA=lectura['availability_365'].max()
MinA=lectura['availability_365'].min()
LimitesA =[MinA,MaxA]
LimitesA
# Out:
# [0, 365]

# %%
RangoA=MaxA-MinA
RangoA
# Out:
# 365

# %%
i=RangoA/ni
i
# Out:
# 23.263772090193346

# %%
intervalosA=np.linspace(MinA,MaxA,16)
intervalosA
# Out:
# array([  0.        ,  24.33333333,  48.66666667,  73.        ,
#         97.33333333, 121.66666667, 146.        , 170.33333333,
#        194.66666667, 219.        , 243.33333333, 267.66666667,
#        292.        , 316.33333333, 340.66666667, 365.        ])

# %%
categoriasA = ["0 a 24.33", "24.33 a 48.67", "48.67 a 73", "73 a 97.33", "97.33 a 121.67", "121.67 a 146", "146 a 170.33", "170.33 a 194.67", "194.67 a 219", "219 a 243.33", "243.33 a 267.67", "267.67 a 292", "292 a 316.33", "316.33 a 340.67", "340.67 a 365"]
lectura['availability_365']=pd.cut(x=lectura['availability_365'], bins=intervalosA, labels=categoriasA)
lectura['availability_365']
# Out:
# 0           340.67 a 365
# 1        316.33 a 340.67
# 2        316.33 a 340.67
# 3        243.33 a 267.67
# 4           267.67 a 292
#               ...
# 26577       340.67 a 365
# 26578    170.33 a 194.67
# 26579    170.33 a 194.67
# 26580    170.33 a 194.67
# 26581       146 a 170.33
# Name: availability_365, Length: 26582, dtype: category
# Categories (15, object): ['0 a 24.33' < '24.33 a 48.67' < '48.67 a 73' < '73 a 97.33' ... '267.67 a 292' < '292 a 316.33' < '316.33 a 340.67' < '340.67 a 365']

# %%
tableA= freq_tbl(lectura["availability_365"])
tableA1= tableA.drop(["cumulative_perc"], axis=1)
tableA2= tableA1.set_index("availability_365")
filtroA=tableA2[tableA2['frequency']>500]
filtroA
# Out:
#                   frequency  percentage
# availability_365
# 340.67 a 365           8965    0.337258
# 316.33 a 340.67        2815    0.105899
# 243.33 a 267.67        1977    0.074374
# 73 a 97.33             1692    0.063652
# 267.67 a 292           1570    0.059063
# 292 a 316.33           1436    0.054022
# 48.67 a 73             1236    0.046498
# 146 a 170.33           1122    0.042209
# 170.33 a 194.67        1089    0.040968
# 219 a 243.33           1052    0.039576
# 121.67 a 146            883    0.033218
# 0 a 24.33               769    0.028929
# 24.33 a 48.67           706    0.026559
# 194.67 a 219            636    0.023926
# 97.33 a 121.67          634    0.023851

# %%
filtroA.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title('Disponibilidad en 365 días en México')
plt.xlabel('Días')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxnr=lectura['number_of_reviews'].max()
Minnr=lectura['number_of_reviews'].min()
Limitesnr =[Minnr,Maxnr]
Limitesnr
# Out:
# [0.0, 135.0]

# %%
Rangonr=Maxnr-Minnr
Rangonr
# Out:
# 135.0

# %%
inr=Rangonr/ni
inr
# Out:
# 8.60440885527699

# %%
intervalosnr=np.linspace(Minnr,Maxnr,16)
intervalosnr
# Out:
# array([  0.,   9.,  18.,  27.,  36.,  45.,  54.,  63.,  72.,  81.,  90.,
#         99., 108., 117., 126., 135.])

# %%
categoriasnr = ["0 a 9", "9 a 18", "18 a 27", "27 a 36", "36 a 45", "45 a 54", "54 a 63", "63 a 72", "72 a 81", "81 a 90", "90 a 99", "99 a 108", "108 a 117", "117 a 126", "126 a 135"]
lectura['number_of_reviews']=pd.cut(x=lectura['number_of_reviews'], bins=intervalosnr, labels=categoriasnr)
lectura['number_of_reviews']

# %%
tablenr= freq_tbl(lectura["number_of_reviews"])
tablenr1= tablenr.drop(["cumulative_perc"], axis=1)
tablenr2= tablenr1.set_index("number_of_reviews")
filtronr=tablenr2[tablenr2['frequency']>500]
filtronr
# Out:
#                    frequency  percentage
# number_of_reviews
# 0 a 9                  10898    0.409977
# 18 a 27                 4353    0.163757
# 9 a 18                  3017    0.113498
# 27 a 36                 1573    0.059175
# 36 a 45                 1239    0.046610
# 45 a 54                  994    0.037394
# 54 a 63                  880    0.033105
# 63 a 72                  729    0.027425
# 72 a 81                  581    0.021857
# 81 a 90                  548    0.020615

# %%
filtronr.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title('Número de críticas en Airbnb México')
plt.xlabel('Críticas')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsl=lectura['review_scores_location'].max()
Minrsl=lectura['review_scores_location'].min()
Limitesrsl =[Minrsl,Maxrsl]
Limitesrsl
# Out:
# [4.2, 5.0]

# %%
Rangorsl=Maxrsl-Minrsl
Rangorsl
# Out:
# 0.7999999999999998

# %%
irsl=Rangorsl/ni
irsl
# Out:
# 0.05098908951275252

# %%
intervalosrsl=np.linspace(Minrsl,Maxrsl,16)
intervalosrsl
# Out:
# array([4.2       , 4.25333333, 4.30666667, 4.36      , 4.41333333,
#        4.46666667, 4.52      , 4.57333333, 4.62666667, 4.68      ,
#        4.73333333, 4.78666667, 4.84      , 4.89333333, 4.94666667,
#        5.        ])

# %%
categoriasrsl = ["4.2 a 4.25", "4.25 a 4.31", "4.31 a 4.36", "4.36 a 4.41", "4.41 a 4.47", "4.47 a 4.52", "4.52 a 4.57", "4.57 a 4.63", "4.63 a 4.68", "4.68 a 4.73", "4.73 a 4.79", "4.79 a 4.84", "4.84 a 4.89", "4.89 a 4.95", "4.95 a 5"]
lectura['review_scores_location']=pd.cut(x=lectura['review_scores_location'], bins=intervalosrsl, labels=categoriasrsl)
lectura['review_scores_location']
# Out:
# 0        4.84 a 4.89
# 1           4.95 a 5
# 2           4.95 a 5
# 3           4.95 a 5
# 4        4.89 a 4.95
#             ...
# 26577    4.84 a 4.89
# 26578    4.84 a 4.89
# 26579    4.84 a 4.89
# 26580    4.84 a 4.89
# 26581    4.84 a 4.89
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (15, object): ['4.2 a 4.25' < '4.25 a 4.31' < '4.31 a 4.36' < '4.36 a 4.41' ... '4.79 a 4.84' < '4.84 a 4.89' < '4.89 a 4.95' < '4.95 a 5']

# %%
tablersl= freq_tbl(lectura["review_scores_location"])
tablersl1= tablersl.drop(["cumulative_perc"], axis=1)
tablersl2= tablersl1.set_index("review_scores_location")
filtrorsl=tablersl2[tablersl2['frequency']>500]
filtrorsl
# Out:
#                         frequency  percentage
# review_scores_location
# 4.95 a 5                    10193    0.383455
# 4.84 a 4.89                  6698    0.251975
# 4.89 a 4.95                  3362    0.126477
# 4.79 a 4.84                  1992    0.074938
# 4.73 a 4.79                  1148    0.043187
# 4.63 a 4.68                   811    0.030509
# 4.68 a 4.73                   777    0.029230

# %%
filtrorsl.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title("Puntuaciones de ubicación en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsv=lectura['review_scores_value'].max()
Minrsv=lectura['review_scores_value'].min()
Limitesrsv =[Minrsv,Maxrsv]
Limitesrsv
# Out:
# [3.9, 5.0]

# %%
Rangorsv=Maxrsv-Minrsv
Rangorsv
# Out:
# 1.1

# %%
irsv=Rangorsv/ni
irsv
# Out:
# 0.07010999808003475

# %%
intervalosrsv=np.linspace(Minrsv,Maxrsv,16)
intervalosrsv
# Out:
# array([3.9       , 3.97333333, 4.04666667, 4.12      , 4.19333333,
#        4.26666667, 4.34      , 4.41333333, 4.48666667, 4.56      ,
#        4.63333333, 4.70666667, 4.78      , 4.85333333, 4.92666667,
#        5.        ])

# %%
categoriasrsv = ["3.9 a 3.97", "3.97 a 4.05", "4.05 a 4.12", "4.12 a 4.19", "4.19 a 4.27", "4.27 a 4.34", "4.34 a 4.41", "4.41 a 4.49", "4.49 a 4.56", "4.56 a 4.63", "4.63 a 4.71", "4.71 a 4.78", "4.78 a 4.85", "4.85 a 4.93", "4.93 a 5"]
lectura['review_scores_value']=pd.cut(x=lectura['review_scores_value'], bins=intervalosrsl, labels=categoriasrsl)
lectura['review_scores_value']
# Out:
# 0        4.73 a 4.79
# 1        4.47 a 4.52
# 2        4.89 a 4.95
# 3        4.89 a 4.95
# 4        4.79 a 4.84
#             ...
# 26577    4.73 a 4.79
# 26578    4.73 a 4.79
# 26579    4.73 a 4.79
# 26580    4.73 a 4.79
# 26581    4.73 a 4.79
# Name: review_scores_value, Length: 26582, dtype: category
# Categories (15, object): ['4.2 a 4.25' < '4.25 a 4.31' < '4.31 a 4.36' < '4.36 a 4.41' ... '4.79 a 4.84' < '4.84 a 4.89' < '4.89 a 4.95' < '4.95 a 5']

# %%
tablersv= freq_tbl(lectura["review_scores_value"])
tablersv1= tablersv.drop(["cumulative_perc"], axis=1)
tablersv2= tablersv1.set_index("review_scores_value")
filtrorsv=tablersv2[tablersv2['frequency']>500]
filtrorsv
# Out:
#                      frequency  percentage
# review_scores_value
# 4.73 a 4.79               6382    0.240087
# 4.95 a 5                  5695    0.214243
# 4.79 a 4.84               3077    0.115755
# 4.84 a 4.89               2649    0.099654
# 4.89 a 4.95               2084    0.078399
# 4.63 a 4.68               1667    0.062712
# 4.68 a 4.73               1569    0.059025
# 4.57 a 4.63                830    0.031224
# 4.47 a 4.52                802    0.030171
# 4.52 a 4.57                631    0.023738

# %%
filtrorsv.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title("Puntuaciones de valor en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsc=lectura['review_scores_communication'].max()
Minrsc=lectura['review_scores_communication'].min()
Limitesrsc =[Minrsc,Maxrsc]
Limitesrsc
# Out:
# [4.18, 5.0]

# %%
Rangorsc=Maxrsc-Minrsc
Rangorsc
# Out:
# 0.8200000000000003

# %%
irsc=Rangorsc/ni
irsc
# Out:
# 0.05226381675057137

# %%
intervalosrsc=np.linspace(Minrsc,Maxrsc,16)
intervalosrsc
# Out:
# array([4.18      , 4.23466667, 4.28933333, 4.344     , 4.39866667,
#        4.45333333, 4.508     , 4.56266667, 4.61733333, 4.672     ,
#        4.72666667, 4.78133333, 4.836     , 4.89066667, 4.94533333,
#        5.        ])

# %%
categoriasrsc = ["4.18 a 4.23", "4.23 a 4.29", "4.29 a 4.34", "4.34 a 4.40", "4.40 a 4.45", "4.45 a 4.51", "4.51 a 4.56", "4.56 a 4.62", "4.62 a 4.67", "4.67 a 4.73", "4.73 a 4.78", "4.78 a 4.84", "4.84 a 4.89", "4.89 a 4.95", "4.95 a 5"]
lectura['review_scores_communication']=pd.cut(x=lectura['review_scores_communication'], bins=intervalosrsc, labels=categoriasrsc)
lectura['review_scores_communication']
# Out:
# 0        4.84 a 4.89
# 1        4.73 a 4.78
# 2        4.89 a 4.95
# 3           4.95 a 5
# 4        4.73 a 4.78
#             ...
# 26577    4.84 a 4.89
# 26578    4.84 a 4.89
# 26579    4.84 a 4.89
# 26580    4.84 a 4.89
# 26581    4.84 a 4.89
# Name: review_scores_communication, Length: 26582, dtype: category
# Categories (15, object): ['4.18 a 4.23' < '4.23 a 4.29' < '4.29 a 4.34' < '4.34 a 4.40' ... '4.78 a 4.84' < '4.84 a 4.89' < '4.89 a 4.95' < '4.95 a 5']

# %%
tablersc= freq_tbl(lectura["review_scores_communication"])
tablersc1= tablersc.drop(["cumulative_perc"], axis=1)
tablersc2= tablersc1.set_index("review_scores_communication")
filtrorsc=tablersc2[tablersc2['frequency']>500]
filtrorsc
# Out:
#                              frequency  percentage
# review_scores_communication
# 4.95 a 5                         10209    0.384057
# 4.84 a 4.89                       7230    0.271989
# 4.89 a 4.95                       3255    0.122451
# 4.78 a 4.84                       1714    0.064480
# 4.73 a 4.78                       1323    0.049771
# 4.62 a 4.67                        702    0.026409
# 4.67 a 4.73                        607    0.022835

# %%
filtrorsc.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightgreen")
plt.title("Puntuaciones de comunicación en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsch=lectura['review_scores_checkin'].max()
Minrsch=lectura['review_scores_checkin'].min()
Limitesrsch =[Minrsch,Maxrsch]
Limitesrsch
# Out:
# [4.25, 5.0]

# %%
Rangorsch=Maxrsch-Minrsch
Rangorsch
# Out:
# 0.75

# %%
irsch=Rangorsch/ni
irsch
# Out:
# 0.047802271418205505

# %%
intervalosrsch=np.linspace(Minrsch,Maxrsch,16)
intervalosrsch
# Out:
# array([4.25, 4.3 , 4.35, 4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75,
#        4.8 , 4.85, 4.9 , 4.95, 5.  ])

# %%
categoriasrsch = ["3.93 a 4.00", "4.00 a 4.07", "4.07 a 4.14", "4.14 a 4.22", "4.22 a 4.29", "4.29 a 4.36", "4.36 a 4.43", "4.43 a 4.50", "4.50 a 4.57", "4.57 a 4.64", "4.64 a 4.71", "4.71 a 4.79", "4.79 a 4.86", "4.86 a 4.93", "4.93 a 5"]
lectura['review_scores_checkin']=pd.cut(x=lectura['review_scores_checkin'], bins=intervalosrsch, labels=categoriasrsch)
lectura['review_scores_checkin']
# Out:
# 0        4.79 a 4.86
# 1        4.79 a 4.86
# 2        4.86 a 4.93
# 3           4.93 a 5
# 4           4.93 a 5
#             ...
# 26577    4.79 a 4.86
# 26578    4.79 a 4.86
# 26579    4.79 a 4.86
# 26580    4.79 a 4.86
# 26581    4.79 a 4.86
# Name: review_scores_checkin, Length: 26582, dtype: category
# Categories (15, object): ['3.93 a 4.00' < '4.00 a 4.07' < '4.07 a 4.14' < '4.14 a 4.22' ... '4.71 a 4.79' < '4.79 a 4.86' < '4.86 a 4.93' < '4.93 a 5']

# %%
tablersch= freq_tbl(lectura["review_scores_checkin"])
tablersch1= tablersch.drop(["cumulative_perc"], axis=1)
tablersch2= tablersch1.set_index("review_scores_checkin")
filtrorsch=tablersch2[tablersch2['frequency']>500]
filtrorsch
# Out:
#                        frequency  percentage
# review_scores_checkin
# 4.93 a 5                    9092    0.342036
# 4.79 a 4.86                 7324    0.275525
# 4.86 a 4.93                 3716    0.139794
# 4.71 a 4.79                 1850    0.069596
# 4.64 a 4.71                 1361    0.051200
# 4.57 a 4.64                  976    0.036717
# 4.50 a 4.57                  742    0.027914

# %%
filtrorsch.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title("Puntuaciones de check-in en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrscl=lectura['review_scores_cleanliness'].max()
Minrscl=lectura['review_scores_cleanliness'].min()
Limitesrscl =[Minrscl,Maxrscl]
Limitesrscl
# Out:
# [3.91, 5.0]

# %%
Rangorscl=Maxrscl-Minrscl
Rangorscl
# Out:
# 1.0899999999999999

# %%
irscl=Rangorscl/ni
irscl
# Out:
# 0.06947263446112532

# %%
intervalosrscl=np.linspace(Minrscl,Maxrscl,16)
intervalosrscl
# Out:
# array([3.91      , 3.98266667, 4.05533333, 4.128     , 4.20066667,
#        4.27333333, 4.346     , 4.41866667, 4.49133333, 4.564     ,
#        4.63666667, 4.70933333, 4.782     , 4.85466667, 4.92733333,
#        5.        ])

# %%
categoriasrscl = ["3.91 a 3.98", "3.98 a 4.06", "4.06 a 4.13", "4.13 a 4.2", "4.2 a 4.27", "4.27 a 4.35", "4.35 a 4.42", "4.42 a 4.49", "4.49 a 4.56", "4.56 a 4.64", "4.64 a 4.71", "4.71 a 4.78", "4.78 a 4.85", "4.85 a 4.93", "4.93 a 5"]
lectura['review_scores_cleanliness']=pd.cut(x=lectura['review_scores_cleanliness'], bins=intervalosrscl, labels=categoriasrscl)
lectura['review_scores_cleanliness']
# Out:
# 0        4.78 a 4.85
# 1        4.64 a 4.71
# 2        4.71 a 4.78
# 3           4.93 a 5
# 4           4.93 a 5
#             ...
# 26577    4.78 a 4.85
# 26578    4.78 a 4.85
# 26579    4.78 a 4.85
# 26580    4.78 a 4.85
# 26581    4.78 a 4.85
# Name: review_scores_cleanliness, Length: 26582, dtype: category
# Categories (15, object): ['3.91 a 3.98' < '3.98 a 4.06' < '4.06 a 4.13' < '4.13 a 4.2' ... '4.71 a 4.78' < '4.78 a 4.85' < '4.85 a 4.93' < '4.93 a 5']

# %%
tablerscl= freq_tbl(lectura["review_scores_cleanliness"])
tablerscl1= tablerscl.drop(["cumulative_perc"], axis=1)
tablerscl2= tablerscl1.set_index("review_scores_cleanliness")
filtrorscl=tablerscl2[tablerscl2['frequency']>500]
filtrorscl
# Out:
#                            frequency  percentage
# review_scores_cleanliness
# 4.93 a 5                        7736    0.291024
# 4.78 a 4.85                     7158    0.269280
# 4.85 a 4.93                     3816    0.143556
# 4.71 a 4.78                     2543    0.095666
# 4.64 a 4.71                     1528    0.057483
# 4.56 a 4.64                      989    0.037206
# 4.49 a 4.56                      980    0.036867

# %%
filtrorscl.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title("Puntuaciones de limpieza en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrsa=lectura['review_scores_accuracy'].max()
Minrsa=lectura['review_scores_accuracy'].min()
Limitesrsa =[Minrsa,Maxrsa]
Limitesrsa
# Out:
# [4.09, 5.0]

# %%
Rangorsa=Maxrsa-Minrsa
Rangorsa
# Out:
# 0.9100000000000001

# %%
irsa=Rangorsa/ni
irsa
# Out:
# 0.05800008932075602

# %%
intervalosrsa=np.linspace(Minrsa,Maxrsa,16)
intervalosrsa
# Out:
# array([4.09      , 4.15066667, 4.21133333, 4.272     , 4.33266667,
#        4.39333333, 4.454     , 4.51466667, 4.57533333, 4.636     ,
#        4.69666667, 4.75733333, 4.818     , 4.87866667, 4.93933333,
#        5.        ])

# %%
categoriasrsa = ["4.09 a 4.15", "4.15 a 4.21", "4.21 a 4.27", "4.27 a 4.33", "4.33 a 4.39", "4.39 a 4.45", "4.45 a 4.51", "4.51 a 4.57", "4.57 a 4.64", "4.64 a 4.7", "4.7 a 4.76", "4.76 a 4.82", "4.82 a 4.88", "4.88 a 4.94", "4.94 a 5"]
lectura['review_scores_accuracy']=pd.cut(x=lectura['review_scores_accuracy'], bins=intervalosrsa, labels=categoriasrsa)
lectura['review_scores_accuracy']
# Out:
# 0        4.82 a 4.88
# 1        4.51 a 4.57
# 2        4.76 a 4.82
# 3        4.88 a 4.94
# 4           4.94 a 5
#             ...
# 26577    4.82 a 4.88
# 26578    4.82 a 4.88
# 26579    4.82 a 4.88
# 26580    4.82 a 4.88
# 26581    4.82 a 4.88
# Name: review_scores_accuracy, Length: 26582, dtype: category
# Categories (15, object): ['4.09 a 4.15' < '4.15 a 4.21' < '4.21 a 4.27' < '4.27 a 4.33' ... '4.76 a 4.82' < '4.82 a 4.88' < '4.88 a 4.94' < '4.94 a 5']

# %%
tablersa= freq_tbl(lectura["review_scores_accuracy"])
tablersa1= tablersa.drop(["cumulative_perc"], axis=1)
tablersa2= tablersa1.set_index("review_scores_accuracy")
filtrorsa=tablersa2[tablersa2['frequency']>500]
filtrorsa
# Out:
#                         frequency  percentage
# review_scores_accuracy
# 4.94 a 5                     8108    0.305018
# 4.82 a 4.88                  7419    0.279099
# 4.88 a 4.94                  3987    0.149989
# 4.76 a 4.82                  2050    0.077120
# 4.7 a 4.76                   1589    0.059777
# 4.64 a 4.7                   1068    0.040178
# 4.57 a 4.64                   623    0.023437
# 4.45 a 4.51                   511    0.019224

# %%
filtrorsa.plot(kind = 'bar', width=0.8, figsize=(10,4), color="lightblue")
plt.title("Puntuaciones de exactitud en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Maxrpm=lectura['reviews_per_month'].max()
Minrpm=lectura['reviews_per_month'].min()
Limitesrpm =[Minrpm,Maxrpm]
Limitesrpm
# Out:
# [0.0, 5.21]

# %%
Rangorpm=Maxrpm-Minrpm
Rangorpm
# Out:
# 5.21

# %%
irpm=Rangorpm/ni
irpm
# Out:
# 0.3320664454518009

# %%
intervalosrpm=np.linspace(Minrpm,Maxrpm,16)
intervalosrpm
# Out:
# array([0.        , 0.34733333, 0.69466667, 1.042     , 1.38933333,
#        1.73666667, 2.084     , 2.43133333, 2.77866667, 3.126     ,
#        3.47333333, 3.82066667, 4.168     , 4.51533333, 4.86266667,
#        5.21      ])

# %%
categoriasrpm = ["0 a 0.35", "0.35 a 0.69", "0.69 a 1.04", "1.04 a 1.39", "1.39 a 1.74", "1.74 a 2.08", "2.08 a 2.43", "2.43 a 2.78", "2.78 a 3.13", "3.13 a 3.47", "3.47 a 3.82", "3.82 a 4.17", "4.17 a 4.52", "4.52 a 4.86", "4.86 a 5.21"]
lectura['reviews_per_month']=pd.cut(x=lectura['reviews_per_month'], bins=intervalosrpm, labels=categoriasrpm)
lectura['reviews_per_month']
# Out:
# 0                NaN
# 1        0.35 a 0.69
# 2           0 a 0.35
# 3        0.69 a 1.04
# 4           0 a 0.35
#             ...
# 26577            NaN
# 26578            NaN
# 26579            NaN
# 26580            NaN
# 26581            NaN
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (15, object): ['0 a 0.35' < '0.35 a 0.69' < '0.69 a 1.04' < '1.04 a 1.39' ... '3.82 a 4.17' < '4.17 a 4.52' < '4.52 a 4.86' < '4.86 a 5.21']

# %%
tablerpm= freq_tbl(lectura["reviews_per_month"])
tablerpm1= tablerpm.drop(["cumulative_perc"], axis=1)
tablerpm2= tablerpm1.set_index("reviews_per_month")
filtrorpm=tablerpm2[tablerpm2['frequency']>500]
filtrorpm
# Out:
#                    frequency  percentage
# reviews_per_month
# 0 a 0.35                8592    0.323226
# 0.35 a 0.69             3216    0.120984
# 1.04 a 1.39             2940    0.110601
# 0.69 a 1.04             2682    0.100895
# 1.39 a 1.74             1593    0.059928
# 1.74 a 2.08             1547    0.058197
# 2.08 a 2.43             1214    0.045670
# 2.43 a 2.78             1026    0.038598
# 2.78 a 3.13              958    0.036039
# 3.13 a 3.47              779    0.029306
# 3.47 a 3.82              559    0.021029

# %%
filtrorpm.plot(kind = 'bar', width=0.8, figsize=(10,4), color="black")
plt.title("Críticas por mes en Airbnb México")
plt.xlabel('Puntuaciones')
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
